# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

# %%
import numpy as np

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read.csv('data/import/BankChurners.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read.csv('data/import/BankChurners.csv')
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df = pd.read_csv('data/import/BankChurners.csv')
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.sample(n=5, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.sample(n=5, random_state=42)
#
# AttributeError: 'NoneType' object has no attribute 'sample'

# %%
df.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
print(df.dtypes)
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
df = df.rename(columns={'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1': 'Inactive_12_mon_1'}, inplace=True)

# %%
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(df.dtypes)
#
# AttributeError: 'NoneType' object has no attribute 'dtypes'

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
df.sample(n=5, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.sample(n=5, random_state=42)
#
# AttributeError: 'NoneType' object has no attribute 'sample'

# %%
df = pd.read_csv('data/import/BankChurners.csv')
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
print(df.dtypes)
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
df.rename(columns={'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1': 'Inactive_12_mon_1'}, inplace=True)
print(df.dtypes)
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
df.rename(columns={'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2': 'Inactive_12_mon_2'}, inplace=True)
print(df.dtypes)
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# Inactive_12_mon_1           float64
# Inactive_12_mon_2           float64
# dtype: object

# %%
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df['Income_Category'].value_counts()
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64

# %%
df['CLIENTNUM'].value_counts()
# Out:
# CLIENTNUM
# 714337233    1
# 768805383    1
# 818770008    1
# 713982108    1
# 769911858    1
#             ..
# 709327383    1
# 806160108    1
# 753327333    1
# 709967358    1
# 714885258    1
# Name: count, Length: 10127, dtype: int64

# %% [markdown]
# #Checking if all data is added in the income category.

# %%
df['Attrition_Flag'].value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %% [markdown]
# #Checking the churning number.

# %% [markdown]
# #installing plotly

# %%
import plotly.express as px
import plotly.io as pio

# %%
fig = px.scatter(df, 
                 x="Customer_Age", 
                 y="Dependent_count", 
                 color="Attrition_Flag")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 5
#       1 fig = px.scatter(df,
#       2                  x="Customer_Age",
#       3                  y="Dependent_count",
#       4                  color="Attrition_Flag")
# ----> 5 fig.show()
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\basedatatypes.py:3436, in BaseFigure.show(self, *args, **kwargs)
#    3403 """
#    3404 Show a figure using either the default renderer(s) or the renderer(s)
#    3405 specified by the renderer argument
#    (...)   3432 None
#    3433 """
#    3434 import plotly.io as pio
# -> 3436 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
# ...

# %%
fig = px.bar(df, x="Income_Category", y='Attrition_Flag')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 fig = px.bar(df, x="Income_Category", y='Attrition_Flag')
# ----> 2 fig.show()
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\basedatatypes.py:3436, in BaseFigure.show(self, *args, **kwargs)
#    3403 """
#    3404 Show a figure using either the default renderer(s) or the renderer(s)
#    3405 specified by the renderer argument
#    (...)   3432 None
#    3433 """
#    3434 import plotly.io as pio
# -> 3436 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import plotly.io as pio

# %%
fig = px.bar(df, x="Income_Category", y='Attrition_Flag')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 2
#       1 fig = px.bar(df, x="Income_Category", y='Attrition_Flag')
# ----> 2 fig.show()
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\basedatatypes.py:3436, in BaseFigure.show(self, *args, **kwargs)
#    3403 """
#    3404 Show a figure using either the default renderer(s) or the renderer(s)
#    3405 specified by the renderer argument
#    (...)   3432 None
#    3433 """
#    3434 import plotly.io as pio
# -> 3436 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
# ...

# %% [markdown]
# #Checking correlation

# %%
df[['Months_on_book', 'Customer_Age']].corr()
# Out:
#                 Months_on_book  Customer_Age
# Months_on_book        1.000000      0.788912
# Customer_Age          0.788912      1.000000

# %% [markdown]
# 'Checking correlation

# %%
df[['Attrition_Flag', 'Avg_Utilization_Ratio']].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df[['Attrition_Flag', 'Avg_Utilization_Ratio']].corr()
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...                  777          11914.0
# ...

# %%
df.insert(1, 'New_Column', df['Attrition_Flag'].apply(lambda x: 1 if x == 'Existing Customer' else 0))
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2044\2939455568.py in ?()
# ----> 1 df.insert(1, 'New_Column', df['Attrition_Flag'].apply(lambda x: 1 if x == 'Existing Customer' else 0))
#       2 df.head(5)
#
# c:\Users\Zoli\OneDrive\Documents\VS Code Projects\Heckathon1_May16\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
# ...

# %%
df.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  New_Column  Customer_Age Gender  \
# 0  768805383  Existing Customer           1            45      M
# 1  818770008  Existing Customer           1            49      F
# 2  713982108  Existing Customer           1            51      M
# 3  769911858  Existing Customer           1            40      F
# 4  709106358  Existing Customer           1            40      M
#
#    Dependent_count Education_Level Marital_Status Income_Category  \
# 0                3     High School        Married     $60K - $80K
# 1                5        Graduate         Single  Less than $40K
# 2                3        Graduate        Married    $80K - $120K
# 3                4     High School        Unknown  Less than $40K
# 4                3      Uneducated        Married     $60K - $80K
#
#   Card_Category  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0          Blue  ...                  777          11914.0
# ...

# %%
df.sample(5)
# Out:
#       CLIENTNUM     Attrition_Flag  New_Column  Customer_Age Gender  \
# 9684  713036208  Existing Customer           1            46      M
# 6895  713261133  Attrited Customer           0            38      M
# 5562  787665258  Attrited Customer           0            47      F
# 3816  710673558  Existing Customer           1            37      M
# 5340  715204083  Existing Customer           1            47      F
#
#       Dependent_count Education_Level Marital_Status Income_Category  \
# 9684                1        Graduate        Married     $40K - $60K
# 6895                4        Graduate        Unknown     $60K - $80K
# 5562                3         Unknown        Married  Less than $40K
# 3816                1     High School         Single     $60K - $80K
# 5340                4       Doctorate         Single  Less than $40K
#
#      Card_Category  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 9684          Blue  ...                 2091           4812.0
# ...

# %%
df.rename(columns={'New_Column': 'Attrited_Num'}, inplace=True)

# %%
df.sample(5)
# Out:
#       CLIENTNUM     Attrition_Flag  Attrited_Num  Customer_Age Gender  \
# 8316  718792758  Existing Customer             1            35      F
# 1489  793222008  Existing Customer             1            32      M
# 6970  708158133  Attrited Customer             0            45      M
# 5182  714058308  Attrited Customer             0            43      F
# 8717  709372608  Existing Customer             1            43      M
#
#       Dependent_count Education_Level Marital_Status Income_Category  \
# 8316                4      Uneducated        Married         Unknown
# 1489                0     High School        Married     $60K - $80K
# 6970                3         College        Married    $80K - $120K
# 5182                5      Uneducated         Single  Less than $40K
# 8717                4      Uneducated        Married     $60K - $80K
#
#      Card_Category  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 8316          Blue  ...                  587           2792.0
# ...

# %%
import plotly.io as pio
import plotly.express as px
import pandas as pd
import numpy as np

df = pd.read_csv('data/import/BankChurners.csv')
df.head(5)


#fig = px.bar(df, x="Attrited_Num", y='Customer_Age')
#fig.show(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.insert(1, 'Attrition_Num', df['Attrition_Flag'].apply(lambda x: 1 if x == 'Existing Customer' else 0))
df.head(5)
# Out:
#    CLIENTNUM  Attrition_Num     Attrition_Flag  Customer_Age Gender  \
# 0  768805383              1  Existing Customer            45      M
# 1  818770008              1  Existing Customer            49      F
# 2  713982108              1  Existing Customer            51      M
# 3  769911858              1  Existing Customer            40      F
# 4  709106358              1  Existing Customer            40      M
#
#    Dependent_count Education_Level Marital_Status Income_Category  \
# 0                3     High School        Married     $60K - $80K
# 1                5        Graduate         Single  Less than $40K
# 2                3        Graduate        Married    $80K - $120K
# 3                4     High School        Unknown  Less than $40K
# 4                3      Uneducated        Married     $60K - $80K
#
#   Card_Category  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0          Blue  ...       12691.0                  777          11914.0
# ...

# %%
fig = px.scatter(df, x="Customer_Age", y="Income_Category", color="Attrition_Flag")
fig.show()

# %% [markdown]
# #It shows that mainly the age 36-59 customers are churning, regardless their income.
